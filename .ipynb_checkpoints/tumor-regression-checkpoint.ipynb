# %%
# upload all import packages
# subjects' info: age, gender, ...summary all the information you can show. image info: size, how many, intensity histogram, ...
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import glob
import pydicom
from pydicom.data import get_testdata_files
import os

# %% [markdown]
# ## PLOT density function individually

# %% [markdown]
# #### image and density plot 1

# %%
base_dir='C:/Users/lliu10/OneDrive - Inside MD Anderson/Documents/Brain-Tumor-Progression'

# %%
ds = pydicom.dcmread(base_dir + '/PGBM-001/04-02-1992-FH-HEADBrain Protocols-79896/11.000000-T1post-80644/1-13.dcm')
plt.imshow(ds.pixel_array, cmap=plt.cm.gray)
plt.savefig('tumor_plot1.png')
# plt.show()

# %%
ds1 = pydicom.dcmread(base_dir+'/PGBM-001/04-02-1992-FH-HEADBrain Protocols-79896/11.000000-T1post-80644/1-13.dcm')
ax = plt.hist(ds1.pixel_array.ravel(), bins = 256)
# plt.show()
plt.savefig('first_plot1.png', transparent = True)

# %% [markdown]
# #### image and density plot 2

# %%
ds = pydicom.dcmread(base_dir+'/PGBM-007/12-29-1992-Mr Rcbv Sequence Fh-74352/37998.000000-T2reg-77099/1-12.dcm')
plt.imshow(ds.pixel_array, cmap=plt.cm.gray)
plt.savefig('tumor_plot2.png')
# plt.show()

# %%
ds2 = pydicom.dcmread(base_dir+'/PGBM-007/12-29-1992-Mr Rcbv Sequence Fh-74352/37998.000000-T2reg-77099/1-12.dcm')
ax = plt.hist(ds2.pixel_array.ravel(), bins = 256)
# plt.show()
plt.savefig('first_plot2.png')

# %%
ds = pydicom.dcmread(base_dir_'/Brain-Tumor-Progression/PGBM-017/08-21-1997-MR RCBV SEQUENCE-73885/37603.000000-FLAIRreg-59258/1-12.dcm')
plt.imshow(ds.pixel_array, cmap=plt.cm.gray)
plt.savefig('tumor_plot3.png')
# plt.show()

# %%
ds3 = pydicom.dcmread('../input/brain-tumor-progression/Brain-Tumor-Progression/PGBM-017/08-21-1997-MR RCBV SEQUENCE-73885/37603.000000-FLAIRreg-59258/1-12.dcm')
ax = plt.hist(ds3.pixel_array.ravel(), bins = 256)
# plt.show()
plt.savefig('first_plot3.png')

# %%
ds = pydicom.dcmread('../input/brain-tumor-progression/Brain-Tumor-Progression/PGBM-020/11-09-1989-HEADBrain Protocols-61674/28721.000000-nCBFreg-99726/1-12.dcm')
plt.imshow(ds.pixel_array, cmap=plt.cm.gray)
plt.savefig('tumor_plot4.png')
# plt.show()

# %%
ds4 = pydicom.dcmread('../input/brain-tumor-progression/Brain-Tumor-Progression/PGBM-020/11-09-1989-HEADBrain Protocols-61674/28721.000000-nCBFreg-99726/1-12.dcm')
ax = plt.hist(ds4.pixel_array.ravel(), bins = 256)
# plt.show()
plt.savefig('first_plot4.png')

# %%
# ds4
# plt.imshow(ds4.pixel_array, cmap=plt.cm.gray)
# plt.show()

# %% [markdown]
# ## Reading Dataset

# %%
# read all the file
df = []
pixels= []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        dataset = pydicom.dcmread(os.path.join(dirname, filename))
        df.append(dataset)
        pixels.append(dataset.pixel_array)

# %%
# dfnames =[]
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         ds = pydicom.read_file(os.path.join(dirname, filename), force = True)
#         df = pd.DataFrame(ds.values())
# #        able to read raw data elements
#         df[0] = df[0].apply(lambda x: pydicom.dataelem.DataElement_from_raw(x) if isinstance(x, pydicom.dataelem.RawDataElement) else x)
#         df['name'] = df[0].apply(lambda x: x.name)
# #         df['value'] = df[0].apply(lambda x: x.value)
#         dfnames.append(df[0].apply(lambda x: x.name))
#         df = df[['name']]

# %% [markdown]
# ### find max length list in dicoms

# %%
biggest = 0
# length of 8798
for i in range (len(df)):
#     i is the 8798 df[i]
    for j in range (len(df[i])):
        if j >biggest:
            biggest = j
    
#     compute length of df 
print(biggest)
# Out:
# 270

# %% [markdown]
# ### locate the list

# %%
location = []
# length of 8798
for i in range (len(df)):
#     i is the 8798 df[i]
    location.append(len(df[i]))
location.index(max(location))
# Out:
# 490

# %%
df[490]
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 196
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.4429.7055.221302824824595206355471223210
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'OTHER']
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.4429.7055.221302824824595206355471223210
# (0008, 0020) Study Date                          DA: '19921229'
# (0008, 0021) Series Date                         DA: '19921229'
# (0008, 0022) Acquisition Date                    DA: '19921229'
# (0008, 0023) Content Date                        DA: '19921229'
# (0008, 0030) Study Time                          TM: '114403.000000'
# (0008, 0031) Series Time                         TM: '112412'
# (0008, 0032) Acquisition Time                    TM: '112413'
# (0008, 0033) Content Time                        TM: '112413'
# (0008, 0050) Accession Number                    SH: '1861197569284517'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'Mr Rcbv Sequence Fh'
# (0008, 103e) Series Description                  LO: 'T1post'
# (0008, 1090) Manufacturer's Model Name           LO: 'Optima MR450w'
# (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.4429.7055.280508691486189243621887734576
#    ---------
# (0008, 1140)  Referenced Image Sequence  2 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.4429.7055.251865228380751652760409462679
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.4429.7055.162449711171914357906610135947
#    ---------
# (0008, 2111) Derivation Description              ST: '2:1 JPEGLOSSLESSPROCFIRSTORDERREDICT'
# (0009, 0010) Private Creator                     LO: 'GEMS_IDEN_01'
# (0009, 1002) [Suite id]                          SH: 'MR01'
# (0009, 1004) [Product id]                        SH: 'SIGNA'
# (0009, 10e3) [Equipment UID]                     UI: 1.3.6.1.4.1.14519.5.2.1.4429.7055.239781225363114264546678815666
# (0010, 0010) Patient's Name                      PN: 'PGBM-007'
# (0010, 0020) Patient ID                          LO: 'PGBM-007'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '063Y'
# (0010, 1020) Patient's Size                      DS: '1.64'
# (0010, 1030) Patient's Weight                    DS: '102.06'
# (0010, 21b0) Additional Patient History          LT: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
# (0012, 0064)  De-identification Method Code Sequence  8 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '113101'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113104'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Structured Content Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113105'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113109'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'Brain-Tumor-Progression'
# (0013, 1013) Private tag data                    LO: '44297055'
# (0018, 0010) Contrast/Bolus Agent                LO: 'Yes   multiha'
# (0018, 0015) Body Part Examined                  CS: 'BRAIN'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: 'NONE'
# (0018, 0022) Scan Options                        CS: ['EDR_GEMS', 'FILTERED_GEMS']
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: '5.0'
# (0018, 0080) Repetition Time                     DS: '666.668'
# (0018, 0081) Echo Time                           DS: '16.0'
# (0018, 0082) Inversion Time                      DS: '0.0'
# (0018, 0083) Number of Averages                  DS: '1.0'
# (0018, 0084) Imaging Frequency                   DS: '63.903926'
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: '1'
# (0018, 0087) Magnetic Field Strength             DS: '1.5'
# (0018, 0088) Spacing Between Slices              DS: '6.5'
# (0018, 0091) Echo Train Length                   IS: '1'
# (0018, 0093) Percent Sampling                    DS: '100.0'
# (0018, 0094) Percent Phase Field of View         DS: '100.0'
# (0018, 0095) Pixel Bandwidth                     DS: '61.0547'
# (0018, 1020) Software Versions                   LO: ['23', 'LX', 'MR Software release:DV22.0_V02_1122.a']
# (0018, 1030) Protocol Name                       LO: 'Brain RCBV'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1088) Heart Rate                          IS: '0'
# (0018, 1090) Cardiac Number of Images            IS: '0'
# (0018, 1094) Trigger Window                      IS: '0'
# (0018, 1100) Reconstruction Diameter             DS: '220.0'
# (0018, 1250) Receive Coil Name                   SH: 'HNS Head'
# (0018, 1310) Acquisition Matrix                  US: [0, 320, 192, 0]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: '90.0'
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: '0.752012'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'GEMS_ACQU_01'
# (0019, 100f) [Horiz. Frame of ref.]              DS: '344.399994'
# (0019, 1011) [Series contrast]                   SS: 2
# (0019, 1012) [Last pseq]                         SS: 0
# (0019, 1017) [Series plane]                      SS: 16
# (0019, 1018) [First scan ras]                    LO: 'I'
# (0019, 1019) [First scan location]               DS: '-55.4343'
# (0019, 101a) [Last scan ras]                     LO: 'S'
# (0019, 101b) [Last scan loc]                     DS: '80.9441'
# (0019, 101e) [Display field of view]             DS: '220.0'
# (0019, 105a) [Acquisition Duration]              FL: 137383616.0
# (0019, 107d) [Second echo]                       DS: '0.0'
# (0019, 107e) [Number of echoes]                  SS: 1
# (0019, 107f) [Table delta]                       DS: '0.0'
# (0019, 1081) [Contiguous]                        SS: 1
# (0019, 1084) [Peak SAR]                          DS: '1.504025'
# (0019, 1087) [Cardiac repetition time]           DS: '0.0'
# (0019, 1088) [Images per cardiac cycle]          SS: 0
# (0019, 108a) [Actual receive gain analog]        SS: 11
# (0019, 108b) [Actual receive gain digital]       SS: 29
# (0019, 108d) [Delay after trigger]               DS: '0.0'
# (0019, 108f) [Swappf]                            SS: 0
# (0019, 1090) [Pause Interval]                    SS: 0
# (0019, 1091) [Pause Time]                        DS: '0.0'
# (0019, 1092) [Slice offset on freq axis]         SL: 0
# (0019, 1093) [Auto Prescan Center Frequency]     DS: '639039260.0'
# (0019, 1094) [Auto Prescan Transmit Gain]        SS: 124
# (0019, 1095) [Auto Prescan Analog receiver gain] SS: 11
# (0019, 1096) [Auto Prescan Digital receiver gain SS: 29
# (0019, 1097) [Bitmap defining CVs]               SL: 16
# (0019, 109b) [Pulse Sequence Mode]               SS: 1
# (0019, 109c) [Pulse Sequence Name]               LO: 'memp'
# (0019, 109d) [Pulse Sequence Date]               DT: '19911114183711'
# (0019, 109e) [Internal Pulse Sequence Name]      LO: 'MEMP'
# (0019, 109f) [Transmitting Coil Type]            SS: 3
# (0019, 10a0) [Surface Coil Type]                 SS: 0
# (0019, 10a1) [Extremity Coil flag]               SS: 0
# (0019, 10a2) [Raw data run number]               SL: 24078
# (0019, 10a3) [Calibrated Field strength]         UL: 0
# (0019, 10a4) [SAT fat/water/bone]                SS: 0
# (0019, 10be) [Projection angle]                  DS: '0.0'
# (0019, 10c0) [Saturation planes]                 SS: 0
# (0019, 10c2) [SAT location R]                    SS: 9990
# (0019, 10c3) [SAT location L]                    SS: 9990
# (0019, 10c4) [SAT location A]                    SS: 9990
# (0019, 10c5) [SAT location P]                    SS: 9990
# (0019, 10c6) [SAT location H]                    SS: 9990
# (0019, 10c7) [SAT location F]                    SS: 9990
# (0019, 10c8) [SAT thickness R/L]                 SS: 0
# (0019, 10c9) [SAT thickness A/P]                 SS: 0
# (0019, 10ca) [SAT thickness H/F]                 SS: 0
# (0019, 10cb) [Phase Contrast flow axis]          SS: 0
# (0019, 10cc) [Velocity encoding]                 SS: 0
# (0019, 10cd) [Thickness disclaimer]              SS: 0
# (0019, 10ce) [Prescan type]                      SS: 2
# (0019, 10cf) [Prescan status]                    SS: 16
# (0019, 10d2) [Projection Algorithm]              SS: 0
# (0019, 10d3) [Projection Algorithm Name]         SH: ''
# (0019, 10d5) [Fractional echo]                   SS: 0
# (0019, 10d7) [Cardiac phase number]              SS: 0
# (0019, 10d8) [Variable echoflag]                 SS: 0
# (0019, 10d9) [Concatenated SAT {# DTI Diffusion  DS: '0.0'
# (0019, 10e2) [Velocity Encode Scale]             DS: '0.0'
# (0019, 10f2) [Fast phases]                       SS: 0
# (0019, 10f9) [Transmit gain]                     DS: '124.0'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.4429.7055.263044885243547117902819474352
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.4429.7055.115091508305443725923895136303
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '11'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '15'
# (0020, 0032) Image Position (Patient)            DS: [-103.185, -124.932, 35.1128]
# (0020, 0037) Image Orientation (Patient)         DS: [0.998349, 0.048036, 0.031495, -0.0471505, 0.998492, -0.0281072]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.4429.7055.108607170609585144320370599096
# (0020, 0060) Laterality                          CS: ''
# (0020, 1002) Images in Acquisition               IS: '22'
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: '35.48467255'
# (0020, 9056) Stack ID                            SH: '1'
# (0020, 9057) In-Stack Position Number            UL: 15
# (0021, 0010) Private Creator                     LO: 'GEMS_RELA_01'
# (0021, 1036) [Image from which prescribed]       SS: 10
# (0021, 104f) [Locations in acquisition]          SS: 22
# (0021, 1050) [Graphically prescribed]            SS: 0
# (0021, 1051) [Rotation from source x rot]        DS: '0.0'
# (0021, 1052) [Rotation from source y rot]        DS: '0.0'
# (0021, 1053) [Rotation from source z rot]        DS: '0.0'
# (0021, 1056) [Num 3D slabs]                      SL: 0
# (0021, 1057) [Locs per 3D slab]                  SL: 0
# (0021, 1058) [Overlaps]                          SL: 0
# (0021, 1059) [Image Filtering 0.5/0.2T]          SL: 0
# (0021, 105a) [Diffusion direction]               SL: 0
# (0021, 105b) [Tagging Flip Angle]                DS: '0.0'
# (0021, 105c) [Tagging Orientation]               DS: '0.0'
# (0021, 105d) [Tag Spacing]                       DS: '0.0'
# (0021, 105e) [RTIA_timer]                        DS: '0.0'
# (0021, 105f) [Fps]                               DS: '0.0'
# (0021, 1081) [Auto window/level alpha]           DS: '0.0'
# (0021, 1082) [Auto window/level beta]            DS: '0.0'
# (0021, 1083) [Auto window/level window]          DS: '0.0'
# (0021, 1084) [Auto window/level level]           DS: '0.0'
# (0023, 0010) Private Creator                     LO: 'GEMS_STDY_01'
# (0023, 1074) [No. of updates to header]          SL: 0
# (0023, 107d) [Indicates study has complete info  SS: 0
# (0025, 0010) Private Creator                     LO: 'GEMS_SERS_01'
# (0025, 1006) [Last pulse sequence used]          SS: 0
# (0025, 1007) [Images in Series]                  SL: 22
# (0025, 1010) [Landmark Counter]                  SL: 0
# (0025, 1011) [Number of Acquisitions]            SS: 1
# (0025, 1014) [Indicates no. of updates to header SL: 0
# (0025, 1017) [Series Complete Flag]              SL: 0
# (0025, 1018) [Number of images archived]         SL: 0
# (0025, 1019) [Last image number used]            SL: 22
# (0027, 0010) Private Creator                     LO: 'GEMS_IMAG_01'
# (0027, 1010) [Scout Type]                        SS: 0
# (0027, 1030) [Foreign Image Revision]            SH: ''
# (0027, 1031) [Imaging Mode]                      SS: 1
# (0027, 1032) [Pulse Sequence]                    SS: 0
# (0027, 1033) [Imaging Options]                   UL: 2048
# (0027, 1035) [Plane Type]                        SS: 16
# (0027, 1040) [RAS letter of image location]      SH: 'S'
# (0027, 1041) [Image location]                    FL: 35.48467254638672
# (0027, 1060) [Image dimension - X]               FL: 320.0
# (0027, 1061) [Image dimension - Y]               FL: 192.0
# (0027, 1062) [Number of Excitations]             FL: 1.0
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.4297, 0.4297]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0106) Smallest Image Pixel Value          SS: 0
# (0028, 0107) Largest Image Pixel Value           SS: 4420
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: '2210.0'
# (0028, 1051) Window Width                        DS: '4420.0'
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0029, 0010) Private Creator                     LO: 'GEMS_IMPS_01'
# (0029, 1015) [Lower range of Pixels1]            SL: 0
# (0029, 1016) [Upper range of Pixels1]            SL: 0
# (0029, 1017) [Lower range of Pixels2]            SL: 0
# (0029, 1018) [Upper range of Pixels2]            SL: 0
# (0029, 1026) [Version of the hdr struct]         SS: 2
# (0029, 1034) [Advantage comp. Overflow]          SL: 16384
# (0029, 1035) [Advantage comp. Underflow]         SL: 0
# (0040, 0244) Performed Procedure Step Start Date DA: '19921229'
# (0040, 0245) Performed Procedure Step Start Time TM: '103901'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'MR RCBV SEQUENCE FH'
# (0043, 0010) Private Creator                     LO: 'GEMS_PARM_01'
# (0043, 1001) [Bitmap of prescan options]         SS: 4
# (0043, 1002) [Gradient offset in X]              SS: -13
# (0043, 1003) [Gradient offset in Y]              SS: 21
# (0043, 1004) [Gradient offset in Z]              SS: -37
# (0043, 1006) [Number of EPI shots]               SS: 0
# (0043, 1007) [Views per segment]                 SS: 0
# (0043, 1008) [Respiratory rate, bpm]             SS: 0
# (0043, 1009) [Respiratory trigger point]         SS: 0
# (0043, 100a) [Type of receiver used]             SS: 1
# (0043, 100b) [DB/dt Peak rate of change of gradi DS: '0.0'
# (0043, 100c) [dB/dt Limits in units of percent]  DS: '100.0'
# (0043, 100d) [PSD estimated limit]               DS: '0.0'
# (0043, 100e) [PSD estimated limit in tesla per s DS: '0.0'
# (0043, 1010) [Window value]                      US: 0
# (0043, 101c) [GE image integrity]                SS: 0
# (0043, 101d) [Level value]                       SS: 0
# (0043, 102c) [Effective echo spacing]            SS: 0
# (0043, 102d) [Filter Mode (String slop field 1 i SH: 's'
# (0043, 102e) [String slop field 2]               SH: ''
# (0043, 102f) [Image Type (real, imaginary, phase SS: 0
# (0043, 1032) [Vas flags]                         SS: 2
# (0043, 1033) [Neg_scanspacing]                   FL: 0.0
# (0043, 1034) [Offset Frequency]                  IS: '0'
# (0043, 1035) [User_usage_tag]                    UL: 0
# (0043, 1036) [User_fill_map_MSW]                 UL: 0
# (0043, 1037) [User_fill_map_LSW]                 UL: 0
# (0043, 1038) [User data 25...User data 48 {User4 FL: Array of 24 elements
# (0043, 1039) [Slop_int_6... slop_int_9]          IS: [1000, 0, 0, 0]
# (0043, 107d) [Recon mode flag word]              US: 1
# (0043, 1081) [GE Coil Name]                      LO: 'C-GE_HNS Head'
# (0043, 1083) [Asset R Factors]                   DS: [1, 1]
# (0043, 1084) [Additional Asset Data]             LO: ['10000', '0', '-1', '0', '', 'NO']
# (0043, 1088) [PURE Acquisition Calibration Serie UI: 1.3.6.1.4.1.14519.5.2.1.4429.7055.360289570858189382523245270727
# (0043, 1089) [Governing Body, dB/dt, and SAR def LO: ['FDA', 'IEC_FIRST_LEVEL', 'IEC_FIRST_LEVEL']
# (0043, 108a) [Private In-Plane Phase Encoding Di CS: 'ROW'
# (0043, 1090) [SAR Definition]                    LO: ['WHOLE_BODY_6_MIN', 'LOCAL_PEAK_6_MIN', 'PARTIAL_BODY_6MIN']
# (0043, 1091) [SAR value]                         DS: [0.752, 1.50402, 0.752012]
# (0043, 1095) [Prescan Reuse String]              LO: 'TG/s1,CF/s5,AS/s5'
# (0043, 1096) [Content Qualification]             CS: 'RESEARCH'
# (0043, 1097) [Image Filtering Parameters]        LO: ['2', '1', '1.5 0.2 0.2 2 64 0.4 1.05', '1.5 0.2 0.2 2 64 0.4 1.05', '1.5 0.2 0.2 2 64 0.4 1.05', '100', '0', '0', 'rev=1;a=75;b=2;c=32;d=8;e=3;f=2;g=1;h=0']
# (0043, 109a) [Rx Stack Identification]           IS: '1'
# (3711, 0010) Private Creator                     LO: 'A.L.I. Technologies, Inc.'
# (3711, 100c) [Original Study UID]                UI: 1.3.6.1.4.1.14519.5.2.1.4429.7055.263044885243547117902819474352
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements

# %%
# df[0].apply(lambda x: pydicom.dataelem.DataElement_from_raw(x) if isinstance(x, pydicom.dataelem.RawDataElement) else x)

# %% [markdown]
# ## Put it into DataFrame

# %%
# put patient information in list
i=0
Modality=[]
PatientAge = []
PatientBirthDate= []
PatientID =[]
PatientIdentityRemoved=[]
PatientName =[]
PatientPosition = []
PatientSex = []
PatientWeight =[]
Rows=[]
Columns=[]
SliceLocation=[]
SpacingBetweenSlices =[]
StudyDate = []
TransmitCoilName= []
for i in range(len(df)):
    PatientAge.append(df[i].PatientAge[0:3])
    PatientBirthDate.append(df[i].PatientBirthDate)
    PatientID.append(df[i].PatientID)
    PatientIdentityRemoved.append(df[i].PatientIdentityRemoved)
    PatientName.append(df[i].PatientName)
    PatientPosition.append(df[i].PatientPosition)
    PatientSex.append(df[i].PatientSex)
    PatientWeight.append(df[i].PatientWeight)
    Modality.append(df[i].Modality)
    Rows.append(df[i].Rows)
    Columns.append(df[i].Columns)
    SliceLocation.append(df[i].SliceLocation)
    SpacingBetweenSlices.append(df[i].SpacingBetweenSlices)
    StudyDate.append(df[i].StudyDate)
#     if "TransmitCoilName" not in df[i]:
#         TransmitCoilName.append("Missing")
#     elif "TransmitCoilName" in df[i]:
#         TransmitCoilName.append(df[i].TransmitCoilName)

# %% [markdown]
# #### create header on dataframes

# %%
frame = pd.DataFrame(np.column_stack([Rows,Columns,SliceLocation,SpacingBetweenSlices,StudyDate,]), 
                     columns=['Rows','Columns','SliceLocation','SpacingBetweenSlices','StudyDate'])

# %% [markdown]
# #### patient dataframe

# %%
patient_frame = pd.DataFrame(np.column_stack([PatientAge, PatientBirthDate, PatientID,PatientIdentityRemoved,PatientName,
                                      PatientPosition,PatientSex,PatientWeight,Modality]), 
                     columns=['PatientAge', 'PatientBirthDate', 'PatientID','PatientIdentityRemoved','PatientName',
                              'PatientPosition','PatientSex','PatientWeight','Modality'])

# %% [markdown]
# ### change data type

# %% [markdown]
# change patient dataframe

# %%
patient_frame['PatientAge'] = patient_frame['PatientAge'].astype(str).astype(int)
patient_frame['PatientWeight'] = patient_frame['PatientWeight'].astype(str).astype(float)

# %%
# change data type

frame['Rows'] = frame['Rows'].astype(str).astype(int)
frame['Columns'] = frame['Columns'].astype(str).astype(int)
frame['SliceLocation'] = frame['SliceLocation'].astype(str).astype(float)
frame['SpacingBetweenSlices'] = frame['SpacingBetweenSlices'].astype(str).astype(float)
frame['StudyDateYear']=frame['StudyDate'].astype(str).str[0:4].astype(int)

# %%
patient_frame
# Out:
#       PatientAge PatientBirthDate PatientID PatientIdentityRemoved  \
# 0             51                   PGBM-001                    YES
# 1             51                   PGBM-001                    YES
# 2             51                   PGBM-001                    YES
# 3             51                   PGBM-001                    YES
# 4             51                   PGBM-001                    YES
# ...          ...              ...       ...                    ...
# 8793          44                   PGBM-009                    YES
# 8794          44                   PGBM-009                    YES
# 8795          44                   PGBM-009                    YES
# 8796          44                   PGBM-009                    YES
# 8797          44                   PGBM-009                    YES
#
#                    PatientName PatientPosition PatientSex  PatientWeight  \
# 0     (P, G, B, M, -, 0, 0, 1)             HFS          M     174.633085
# 1     (P, G, B, M, -, 0, 0, 1)             HFS          M     174.633085
# 2     (P, G, B, M, -, 0, 0, 1)             HFS          M     174.633085
# 3     (P, G, B, M, -, 0, 0, 1)             HFS          M     174.633085
# 4     (P, G, B, M, -, 0, 0, 1)             HFS          M     174.633085
# ...                        ...             ...        ...            ...
# 8793  (P, G, B, M, -, 0, 0, 9)             HFS          F      56.190000
# 8794  (P, G, B, M, -, 0, 0, 9)             HFS          F      56.190000
# 8795  (P, G, B, M, -, 0, 0, 9)             HFS          F      56.190000
# 8796  (P, G, B, M, -, 0, 0, 9)             HFS          F      56.190000
# 8797  (P, G, B, M, -, 0, 0, 9)             HFS          F      56.190000
#
#      Modality
# 0          MR
# 1          MR
# 2          MR
# 3          MR
# 4          MR
# ...       ...
# 8793       MR
# 8794       MR
# 8795       MR
# 8796       MR
# 8797       MR
#
# [8798 rows x 9 columns]

# %%
frame
# Out:
#       Rows  Columns  SliceLocation  SpacingBetweenSlices StudyDate  \
# 0      320      260      27.855980                   6.5  19911119
# 1      320      260     -63.144017                   6.5  19911119
# 2      320      260      79.855980                   6.5  19911119
# 3      320      260     -56.644016                   6.5  19911119
# 4      320      260     -37.144022                   6.5  19911119
# ...    ...      ...            ...                   ...       ...
# 8793   320      260     -65.768779                   6.5  19910103
# 8794   320      260      51.231217                   6.5  19910103
# 8795   320      260     -13.768782                   6.5  19910103
# 8796   320      260      57.731219                   6.5  19910103
# 8797   320      260      44.731218                   6.5  19910103
#
#       StudyDateYear
# 0              1991
# 1              1991
# 2              1991
# 3              1991
# 4              1991
# ...             ...
# 8793           1991
# 8794           1991
# 8795           1991
# 8796           1991
# 8797           1991
#
# [8798 rows x 6 columns]

# %%
# Defining a function to view the distribution of the categorical variables
def plotFrequencyTable(df, catColName):
    '''
    This function is used to plot the frequency table of the specified categorical variable
    @df (dataframe) - Dataframe for which frequency table is to be plotted
    @catColName (string) - Column name for which frequency table is to be plotted
    '''
    sns.countplot(x=catColName, data=df)
    plt.title(catColName)
    plt.xticks(rotation = 90)
    plt.show();

# %%
plt.subplot(2,2,1)
plotFrequencyTable(patient_frame,'PatientSex')

# %%
plt.subplot(2,2,1)
plotFrequencyTable(patient_frame,'PatientPosition')

# %%
plt.subplot(2,2,1)
plotFrequencyTable(patient_frame,'PatientIdentityRemoved')

# %%
# # ADD rows and columns for image size
# frame['Image_Size'] = frame['Rows']*frame['Columns']
# frame['Slice_Location']=frame.get('SliceLocation', '(missing)')
